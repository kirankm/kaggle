# %% [markdown]
# # Import Libraries

# %%
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import matplotlib.image as mpimg


# %matplotlib inline

# %% [markdown]
# # Define Variables

# %%
path = "/home/jupyter/study/kaggle/plant_pathology/"
data_path = path +"data/"
output_path = path+"output/"
models = output_path+"models/"
img_path = data_path+"images/"

# %% [markdown]
# # Initial Analysis

# %%
img = plt.imread(img_path+"Train_30.jpg")
img.shape
# Out:
# (1365, 2048, 3)

# %%
img = mpimg.imread(img_path+"Test_30.jpg")
plt.imshow(img)

# %%
### images sizes are 1365* 2048 so we are losing info at small size

# %% [markdown]
# # Reading Data

# %% [markdown]
# ## Get Label DF

# %%
label_df = pd.read_csv(data+"train.csv")
label_df_lbe = pd.melt(label_df, id_vars = "image_id", value_vars=label_df.columns[1:])
label_df = label_df_lbe.loc[label_df_lbe.value == 1].drop("value", axis = 1).reset_index(drop = True)
label_df.set_index("image_id", inplace= True)

# %%
# def get_label(file):
#     img_name = split(file)[1]
#     x = img_name.split(".")[0]
#     tmp = label_df[label_df.image_id == x]
#     return [tmp["healthy"].values[0], tmp["multiple_diseases"].values[0], 
#             tmp["rust"].values[0], tmp["scab"].values[0]]

# %%
def get_label(file):
    img_name = split(file)[1]
    x = img_name.split(".")[0]
    return label_df.loc[x].values[0]

# %% [markdown]
# ## Setup the data loader

# %%
src = ImageList.from_folder(path = data_path+"train/").split_by_rand_pct(.2)

# %%
src
# Out:
# ItemLists;
#
# Train: ImageList (1457 items)
# Image (3, 1365, 2048),Image (3, 1365, 2048),Image (3, 1365, 2048),Image (3, 1365, 2048),Image (3, 1365, 2048)
# Path: /home/jupyter/study/kaggle/plant_pathology/data/train;
#
# Valid: ImageList (364 items)
# Image (3, 1365, 2048),Image (3, 1365, 2048),Image (3, 1365, 2048),Image (3, 1365, 2048),Image (3, 1365, 2048)
# Path: /home/jupyter/study/kaggle/plant_pathology/data/train;
#
# Test: None

# %%
data_path
# Out:
# '/home/jupyter/study/kaggle/plant_pathology/data/'

# %%
np.random.seed(42)
src = (ImageList.from_csv(path = data_path, csv_name = "train2.csv", folder = "train")
     .split_by_rand_pct(0.2)
     .label_from_func(get_label))

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.2, max_warp=0.1, max_zoom=1.02)
data = (src.transform(tfms = tfms,  size=128).databunch().normalize(imagenet_stats))

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# # Training Model

# %%
arch = models.resnet34

# %%
learn = cnn_learner(data, arch, metrics=[error_rate])

# %%
# learn.lr_find()
# learn.recorder.plot()

# %%
lr = 5e-2
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.398170</td>
#       <td>1.024029</td>
#       <td>0.239011</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.215972</td>
#       <td>1.463130</td>
#       <td>0.175824</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.061249</td>
#       <td>0.649200</td>
#       <td>0.131868</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.860552</td>
#       <td>0.436362</td>
#       <td>0.140110</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.690945</td>
#       <td>0.400239</td>
#       <td>0.126374</td>
#       <td>01:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.model_dir =

# %%
help(learn.save)
# Out:
# Help on method save in module fastai.basic_train:
#
# save(file: Union[pathlib.Path, str, _io.BufferedWriter, _io.BytesIO] = None, return_path: bool = False, with_opt: bool = True) method of fastai.basic_train.Learner instance
#     Save model and optimizer state (if `with_opt`) with `file` to `self.model_dir`. `file` can be file-like (file or buffer)

# %%
learn.model_dir = models

# %%
learn.save('stage-1-rn50')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 02:36<01:44]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.399043</td>
#       <td>#na#</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.419850</td>
#       <td>#na#</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.424254</td>
#       <td>#na#</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='22', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.91% [20/22 00:46<00:04 0.9296]
#     </div>
